# %%
import numpy as np
import pandas as pd

hr_df=pd.read_csv('hr_data.csv')

# %%
hr_df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
type(hr_df)
# Out:
# pandas.core.frame.DataFrame

# %%
hr_df.shape
# Out:
# (14999, 9)

# %% [markdown]
# #Numerical Analysis

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
hr_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
#Loading our Employee satisfaction file
s_df=pd.read_excel('employee_satisfaction_evaluation.xlsx')

# %%
s_df.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
s_df.shape
# Out:
# (14999, 3)

# %%
#Merging and joining
main_df = hr_df.set_index('employee_id').join(s_df.set_index('EMPLOYEE #'))
main_df = main_df.reset_index()

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 11 columns]

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
#  9   satisfaction_level     14972 non-null  float64
#  10  last_evaluation        14972 non-null  float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.3+ MB

# %%
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# 352           3150               4                   262                   6
# 376           3250               4                   296                   2
# 402           3405               5                   275                   5
# 427          78130               3                   180                   4
# 442           3635               5                   229                   5
# 468           3755               5                   245                   5
# 543           4150               5                   237                   5
# 892          43615               4                   276                   5
# 1588         42185               5                   264                   5
# 1934         11895               4                   225                   5
# 2343         14170               3                   115                   2
# 2743         16445               5                   149                   2
# 3170         18980               5                   186                   2
# 3609         21580               3                   263                   2
# 3776         22555               4                   214                   3
# 4122         24505               3                   192                   3
# 4740         27950               3                   253                   3
# 5028         29640               4                   180                   4
# 6453         38090               5                   166                   2
# 7005         41535               4                   150                   3
# 7516         44460               4                   264                   3
# 8630         50960               4                   167                   3
# 9455         55770               4                   270                   3
# 9901         58630               5                   252                   3
# 10647        62595               4                   165                   3
# 10962        64350               5                   233                   3
# 11575        20215               3                   192                   7
# 11967        70005               3                   148                   3
# 12422        72475               5                   257                   5
# 12853        74880               3                   136                   2
# 13482        78780               3                   207                   7
# 13925        81315               3                   133                   3
#
#        Work_accident  left  promotion_last_5years   department  salary  \
# 18                 1     1                      1        sales     low
# 19                 0     1                      0        sales     low
# 33                 0     1                      0           hr     low
# 53                 0     1                      0      support     low
# 72                 0     1                      0  product_mng    high
# 92                 0     1                      0        sales     low
# 107                0     1                      0   accounting  medium
# 120                1     1                      0    technical     low
# 137                0     1                      0   management     low
# 175                0     1                      0        sales     low
# 191                1     1                      0    technical  medium
# 352                0     1                      0      support     low
# 376                0     1                      0           IT  medium
# 402                0     1                      0        sales     low
# 427                0     1                      0    technical  medium
# 442                0     1                      0   management     low
# 468                0     1                      0        sales     low
# 543                0     1                      0        sales  medium
# 892                0     1                      0      support     low
# 1588               0     1                      0           IT  medium
# 1934               0     1                      0        sales  medium
# 2343               1     0                      0      support     low
# 2743               0     0                      0        RandD     low
# 3170               0     0                      0    technical  medium
# 3609               1     0                      0        sales  medium
# 3776               0     0                      0    technical  medium
# 4122               0     0                      0    marketing    high
# 4740               0     0                      0    marketing  medium
# 5028               0     0                      0  product_mng  medium
# 6453               0     0                      0    technical    high
# 7005               0     0                      0    technical     low
# 7516               0     0                      0    technical     low
# 8630               1     0                      0    technical     low
# 9455               0     0                      0  product_mng     low
# 9901               0     0                      0      support  medium
# 10647              0     0                      0    technical     low
# 10962              0     0                      0      support     low
# 11575              0     0                      0   management    high
# 11967              0     0                      0           IT     low
# 12422              0     1                      0    technical  medium
# 12853              0     0                      0           hr    high
# 13482              0     0                      1   management  medium
# 13925              0     0                      0        sales  medium
#
#        satisfaction_level  last_evaluation
# 18                    NaN              NaN
# 19                    NaN             0.89
# 33                    NaN              NaN
# 53                    NaN              NaN
# 72                    NaN              NaN
# 92                    NaN              NaN
# 107                   NaN              NaN
# 120                   NaN              NaN
# 137                   NaN              NaN
# 175                   NaN              NaN
# 191                  0.92              NaN
# 352                   NaN             0.91
# 376                  0.56              NaN
# 402                   NaN             1.00
# 427                   NaN             0.60
# 442                  0.77              NaN
# 468                   NaN             0.92
# 543                  0.89              NaN
# 892                  0.74              NaN
# 1588                  NaN             0.81
# 1934                 0.78              NaN
# 2343                  NaN             0.97
# 2743                 0.62              NaN
# 3170                  NaN              NaN
# 3609                 0.95              NaN
# 3776                  NaN             0.68
# 4122                 0.86              NaN
# 4740                  NaN             0.95
# 5028                 0.64              NaN
# 6453                  NaN             0.78
# 7005                 0.82              NaN
# 7516                  NaN             0.97
# 8630                 0.90              NaN
# 9455                  NaN             0.88
# 9901                 0.92              NaN
# 10647                 NaN             0.69
# 10962                0.65              NaN
# 11575                 NaN              NaN
# 11967                0.82              NaN
# 12422                 NaN             1.00
# 12853                 NaN             0.70
# 13482                0.58              NaN
# 13925                 NaN             0.75

# %%
main_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# std         0.351719      0.425924               0.144281            0.248714
# min         0.000000      0.000000               0.000000            0.090000
# 25%         0.000000      0.000000               0.000000            0.440000
# 50%         0.000000      0.000000               0.000000            0.640000
# 75%         0.000000      0.000000               0.000000            0.820000
# max         1.000000      1.000000               1.000000            1.000000
#
#        last_evaluation
# count     14972.000000
# mean          0.716125
# std           0.171138
# min           0.360000
# 25%           0.560000
# 50%           0.720000
# 75%           0.870000
# max           1.000000

# %%
main_df.fillna(main_df.mean(),inplace=True)  # fill with mode for low variance
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
main_df[main_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [employee_id, number_project, average_montly_hours, time_spend_company, Work_accident, left, promotion_last_5years, department, salary, satisfaction_level, last_evaluation]
# Index: []

# %%
main_df.loc[main_df['employee_id']==3794]
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 18         3794               2                   160                   3
#
#     Work_accident  left  promotion_last_5years department salary  \
# 18              1     1                      1      sales    low
#
#     satisfaction_level  last_evaluation
# 18             0.61283         0.716125

# %%
main_df.drop(columns='employee_id',inplace=True)

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
main_df['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
main_df.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# RandD                  134   121                     27           487.80000
# accounting              96   204                     14           446.68283
# hr                      89   215                     15           442.53566
# management             103    91                     69           391.76566
# marketing              138   203                     43           530.62283
# product_mng            132   198                      0           559.19566
# sales                  587  1014                    100          2543.77981
# support                345   555                     20          1377.90849
# technical              381   697                     28          1653.37264
#
#              last_evaluation
# department
# IT                879.452250
# RandD             560.446125
# accounting        550.706125
# hr                524.006125
# management        456.234499
# marketing         613.946125
# product_mng       644.662250
# sales            2938.236749
# support          1611.534499
# technical        1961.930624

# %%
main_df.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# RandD             0.170267  0.153748               0.034307
# accounting        0.125163  0.265971               0.018253
# hr                0.120433  0.290934               0.020298
# management        0.163492  0.144444               0.109524
# marketing         0.160839  0.236597               0.050117
# product_mng       0.146341  0.219512               0.000000
# sales             0.141787  0.244928               0.024155
# support           0.154778  0.248991               0.008973
# technical         0.140074  0.256250               0.010294
#
#              satisfaction_level  last_evaluation
# department
# IT                     0.617908         0.716750
# RandD                  0.619822         0.712130
# accounting             0.582377         0.718000
# hr                     0.598830         0.709075
# management             0.621850         0.724182
# marketing              0.618442         0.715555
# product_mng            0.619951         0.714703
# sales                  0.614440         0.709719
# support                0.618173         0.722985
# technical              0.607858         0.721298

# %% [markdown]
# #Data Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_corr(df,size=10):

    corr=df.corr()
    fig,ax=plt.subplots(figsize=(size,size))
    cax=ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)),corr.columns,rotation='vertical')
    plt.yticks(range(len(corr.columns)),corr.columns)

plot_corr(main_df)

# %%
sns.barplot(x='left',y='satisfaction_level',data=main_df)

# %%
sns.barplot(x='promotion_last_5years',y='satisfaction_level',data=main_df,hue='left')

# %%
sns.pairplot(main_df,hue='left')

# %% [markdown]
# #Data Preprocessing

# %%
y=main_df[['department','salary']]

# %%
y
# Out:
#       department  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support     low
# 14995    support     low
# 14996    support     low
# 14997    support     low
# 14998    support     low
#
# [14999 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

k = le.fit_transform(main_df['salary'])

# %%
k
# Out:
# array([1, 2, 2, ..., 1, 1, 1])

# %%
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  salary  \
# 0                  0     1                      0      sales     low
# 1                  0     1                      0      sales  medium
# 2                  0     1                      0      sales  medium
# 3                  0     1                      0      sales     low
# 4                  0     1                      0      sales     low
# ...              ...   ...                    ...        ...     ...
# 14994              0     1                      0    support     low
# 14995              0     1                      0    support     low
# 14996              0     1                      0    support     low
# 14997              0     1                      0    support     low
# 14998              0     1                      0    support     low
#
#        satisfaction_level  last_evaluation
# 0                    0.38             0.53
# 1                    0.80             0.86
# 2                    0.11             0.88
# 3                    0.72             0.87
# 4                    0.37             0.52
# ...                   ...              ...
# 14994                0.40             0.57
# 14995                0.37             0.48
# 14996                0.37             0.53
# 14997                0.11             0.96
# 14998                0.37             0.52
#
# [14999 rows x 10 columns]

# %%
main_df['salary_num']=k

# %%
main_df.loc[main_df['salary']=='high']
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 72                  2                   149                   3
# 111                 6                   289                   4
# 189                 2                   156                   3
# 267                 2                   129                   3
# 306                 2                   149                   3
# ...               ...                   ...                 ...
# 14829               2                   148                   3
# 14868               2                   130                   3
# 14902               2                   159                   3
# 14941               2                   131                   3
# 14980               5                   238                   5
#
#        Work_accident  left  promotion_last_5years   department salary  \
# 72                 0     1                      0  product_mng   high
# 111                0     1                      0           hr   high
# 189                0     1                      0    technical   high
# 267                0     1                      0    technical   high
# 306                0     1                      0    marketing   high
# ...              ...   ...                    ...          ...    ...
# 14829              0     1                      0    marketing   high
# 14868              0     1                      0      support   high
# 14902              0     1                      0           hr   high
# 14941              0     1                      0        RandD   high
# 14980              0     1                      0    technical   high
#
#        satisfaction_level  last_evaluation  salary_num
# 72                0.61283         0.716125           0
# 111               0.09000         0.850000           0
# 189               0.44000         0.510000           0
# 267               0.45000         0.530000           0
# 306               0.37000         0.460000           0
# ...                   ...              ...         ...
# 14829             0.45000         0.570000           0
# 14868             0.43000         0.550000           0
# 14902             0.45000         0.460000           0
# 14941             0.43000         0.490000           0
# 14980             0.76000         0.890000           0
#
# [1237 rows x 11 columns]

# %%
main_df.drop(['salary'],axis=1,inplace=True)
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years department  \
# 0                  0     1                      0      sales
# 1                  0     1                      0      sales
# 2                  0     1                      0      sales
# 3                  0     1                      0      sales
# 4                  0     1                      0      sales
# ...              ...   ...                    ...        ...
# 14994              0     1                      0    support
# 14995              0     1                      0    support
# 14996              0     1                      0    support
# 14997              0     1                      0    support
# 14998              0     1                      0    support
#
#        satisfaction_level  last_evaluation  salary_num
# 0                    0.38             0.53           1
# 1                    0.80             0.86           2
# 2                    0.11             0.88           2
# 3                    0.72             0.87           1
# 4                    0.37             0.52           1
# ...                   ...              ...         ...
# 14994                0.40             0.57           1
# 14995                0.37             0.48           1
# 14996                0.37             0.53           1
# 14997                0.11             0.96           1
# 14998                0.37             0.52           1
#
# [14999 rows x 10 columns]

# %%
z = le.fit_transform(main_df['department'])
main_df['department_name']=z
main_df.drop(['department'],axis=1,inplace=True)
main_df
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  left  promotion_last_5years  satisfaction_level  \
# 0                  0     1                      0                0.38
# 1                  0     1                      0                0.80
# 2                  0     1                      0                0.11
# 3                  0     1                      0                0.72
# 4                  0     1                      0                0.37
# ...              ...   ...                    ...                 ...
# 14994              0     1                      0                0.40
# 14995              0     1                      0                0.37
# 14996              0     1                      0                0.37
# 14997              0     1                      0                0.11
# 14998              0     1                      0                0.37
#
#        last_evaluation  salary_num  department_name
# 0                 0.53           1                7
# 1                 0.86           2                7
# 2                 0.88           2                7
# 3                 0.87           1                7
# 4                 0.52           1                7
# ...                ...         ...              ...
# 14994             0.57           1                8
# 14995             0.48           1                8
# 14996             0.53           1                8
# 14997             0.96           1                8
# 14998             0.52           1                8
#
# [14999 rows x 10 columns]

# %%
X = main_df.drop(['left'],axis=1)
X
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 0                   2                   157                   3
# 1                   5                   262                   6
# 2                   7                   272                   4
# 3                   5                   223                   5
# 4                   2                   159                   3
# ...               ...                   ...                 ...
# 14994               2                   151                   3
# 14995               2                   160                   3
# 14996               2                   143                   3
# 14997               6                   280                   4
# 14998               2                   158                   3
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 0                  0                      0                0.38
# 1                  0                      0                0.80
# 2                  0                      0                0.11
# 3                  0                      0                0.72
# 4                  0                      0                0.37
# ...              ...                    ...                 ...
# 14994              0                      0                0.40
# 14995              0                      0                0.37
# 14996              0                      0                0.37
# 14997              0                      0                0.11
# 14998              0                      0                0.37
#
#        last_evaluation  salary_num  department_name
# 0                 0.53           1                7
# 1                 0.86           2                7
# 2                 0.88           2                7
# 3                 0.87           1                7
# 4                 0.52           1                7
# ...                ...         ...              ...
# 14994             0.57           1                8
# 14995             0.48           1                8
# 14996             0.53           1                8
# 14997             0.96           1                8
# 14998             0.52           1                8
#
# [14999 rows x 9 columns]

# %%
y = main_df['left']
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 5164                4                   217                   2
# 13146               4                   271                   4
# 1683                2                   135                   3
# 5457                3                   231                   3
# 12549               2                   138                   3
# ...               ...                   ...                 ...
# 8680                5                   201                   6
# 2581                5                   152                   3
# 1440                4                   248                   5
# 8229                3                   230                   2
# 11600               4                   151                   3
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 5164               0                      0                0.54
# 13146              0                      1                0.80
# 1683               0                      0                0.44
# 5457               0                      0                0.96
# 12549              0                      0                0.41
# ...              ...                    ...                 ...
# 8680               0                      0                0.15
# 2581               0                      0                0.63
# 1440               0                      0                0.82
# 8229               0                      0                0.65
# 11600              0                      0                0.95
#
#        last_evaluation  salary_num  department_name
# 5164              0.94           2                8
# 13146             0.94           2                7
# 1683              0.54           1                8
# 5457              0.75           1                9
# 12549             0.47           1                7
# ...                ...         ...              ...
# 8680              0.96           1                8
# 2581              0.96           1                0
# 1440              0.93           2                6
# 8229              0.56           0                0
# 11600             0.75           2                6
#
# [10499 rows x 9 columns]

# %%
X_test
# Out:
#        number_project  average_montly_hours  time_spend_company  \
# 5753                2                   286                   3
# 11792               3                   265                   3
# 5274                3                   243                   3
# 4803                2                   177                   5
# 2164                4                   149                   2
# ...               ...                   ...                 ...
# 420                 6                   268                   4
# 11362               4                   124                   2
# 8372                6                   242                   6
# 3347                4                   275                   3
# 758                 2                   127                   3
#
#        Work_accident  promotion_last_5years  satisfaction_level  \
# 5753               0                      0                0.52
# 11792              0                      0                0.56
# 5274               1                      0                0.95
# 4803               0                      0                0.27
# 2164               0                      0                0.97
# ...              ...                    ...                 ...
# 420                0                      0                0.09
# 11362              0                      0                0.43
# 8372               0                      0                0.36
# 3347               0                      0                0.45
# 758                0                      0                0.39
#
#        last_evaluation  salary_num  department_name
# 5753              0.53           2                7
# 11792             0.74           2                8
# 5274              0.73           2                7
# 4803              0.69           1                1
# 2164              0.66           1                2
# ...                ...         ...              ...
# 420               0.96           2                9
# 11362             0.65           2                7
# 8372              0.56           2                8
# 3347              0.39           2                0
# 758               0.54           1                7
#
# [4500 rows x 9 columns]

# %% [markdown]
# #Model classification

# %% [markdown]
# ##Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
scores_dict = {}
dt=DecisionTreeClassifier()

dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction_dt=dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
prediction_dt.size
# Out:
# 4500

# %%
y_test
# Out:
# 5753     0
# 11792    0
# 5274     0
# 4803     0
# 2164     0
#         ..
# 420      1
# 11362    0
# 8372     0
# 3347     0
# 758      1
# Name: left, Length: 4500, dtype: int64

# %%
accuracy_dt=accuracy_score(y_test,prediction_dt)*100
scores_dict['DecisionTreeClassifier'] = accuracy_dt
accuracy_dt
# Out:
# 97.64444444444445

# %%
custom_dt=[[10,500,10,6,0,0.20,0.89,0,8]]

# %%
print(int(dt.predict(custom_dt)))
# Out:
# 1
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"

# %%
category=['Employee will stay','Employee will leave']

# %%
category[int(dt.predict(custom_dt))]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
# 'Employee will leave'

# %%
dt.feature_importances_
# Out:
# array([1.09689386e-01, 1.29063075e-01, 1.49439908e-01, 7.68800037e-04,
#        4.43469613e-04, 4.86379860e-01, 1.08085524e-01, 6.24587544e-03,
#        9.88410118e-03])

# %%
feature_importance = pd.DataFrame(dt.feature_importances_,index=X_train.columns,columns=['Importance']).sort_values('Importance',ascending=False)
feature_importance
# Out:
#                        Importance
# satisfaction_level       0.486380
# time_spend_company       0.149440
# average_montly_hours     0.129063
# number_project           0.109689
# last_evaluation          0.108086
# department_name          0.009884
# salary_num               0.006246
# Work_accident            0.000769
# promotion_last_5years    0.000443

# %% [markdown]
# ##KNN algorithm
# Data processing of the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler().fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %%
X_train_std
# Out:
# array([[ 0.15500488,  0.31543204, -1.0224571 , ...,  1.29769529,
#          1.04696268,  0.73576246],
#        [ 0.15500488,  1.39822459,  0.3371499 , ...,  1.29769529,
#          1.04696268,  0.3870616 ],
#        [-1.47239132, -1.32880849, -0.3426536 , ..., -1.0424706 ,
#         -0.55281336,  0.73576246],
#        ...,
#        [ 0.15500488,  0.93703517,  1.0169534 , ...,  1.23919114,
#          1.04696268,  0.03836075],
#        [-0.65869322,  0.57610432, -1.0224571 , ..., -0.9254623 ,
#         -2.15258941, -2.05384438],
#        [ 0.15500488, -1.00798107, -0.3426536 , ...,  0.18611649,
#          1.04696268,  0.03836075]])

# %%
X_test_std
# Out:
# array([[-1.47239132,  1.69900029, -0.3426536 , ..., -1.10097474,
#          1.04696268,  0.3870616 ],
#        [-0.65869322,  1.2779143 , -0.3426536 , ...,  0.12761235,
#          1.04696268,  0.73576246],
#        [-0.65869322,  0.8367766 , -0.3426536 , ...,  0.0691082 ,
#          1.04696268,  0.3870616 ],
#        ...,
#        [ 1.78240107,  0.81672489,  1.6967569 , ..., -0.9254623 ,
#          1.04696268,  0.73576246],
#        [ 0.15500488,  1.47843144, -0.3426536 , ..., -1.9200328 ,
#          1.04696268, -2.05384438],
#        [-1.47239132, -1.4892222 , -0.3426536 , ..., -1.0424706 ,
#         -0.55281336,  0.3870616 ]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_std,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
prediction_knn=knn.predict(X_test_std)

# %%
accuracy_knn = accuracy_score(y_test,prediction_knn)*100
scores_dict['KNeighborsClassifier'] = accuracy_score(y_test,prediction_knn)*100
accuracy_knn
# Out:
# 96.04444444444444

# %%
prediction_knn
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
y_test
# Out:
# 5753     0
# 11792    0
# 5274     0
# 4803     0
# 2164     0
#         ..
# 420      1
# 11362    0
# 8372     0
# 3347     0
# 758      1
# Name: left, Length: 4500, dtype: int64

# %%
k_range=range(1,26)
scores={}
scores_list=[]

for k in k_range:
    knn=KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_std,y_train)
    prediction_knn=knn.predict(X_test_std)
    scores[k]=accuracy_score(y_test,prediction_knn)*100
    scores_list.append(accuracy_score(y_test,prediction_knn))

# %%
scores
# Out:
# {1: 96.93333333333334,
#  2: 96.62222222222222,
#  3: 96.04444444444444,
#  4: 96.24444444444444,
#  5: 95.71111111111111,
#  6: 96.11111111111111,
#  7: 95.97777777777777,
#  8: 95.91111111111111,
#  9: 95.64444444444445,
#  10: 95.73333333333333,
#  11: 95.31111111111112,
#  12: 95.53333333333333,
#  13: 95.31111111111112,
#  14: 95.46666666666667,
#  15: 95.19999999999999,
#  16: 95.26666666666667,
#  17: 95.06666666666666,
#  18: 95.15555555555557,
#  19: 95.0,
#  20: 95.06666666666666,
#  21: 94.88888888888889,
#  22: 94.93333333333334,
#  23: 94.77777777777779,
#  24: 94.84444444444445,
#  25: 94.82222222222222}

# %%
max(scores_list)
# Out:
# 0.9693333333333334

# %%
plt.plot(k_range,scores_list)

# %%
X_knn = np.array([[10,500,10,6,0,0.20,0.89,0,8]])
X_knn_std=sc.transform(X_knn)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   "X does not have valid feature names, but"

# %%
X_knn_std
# Out:
# array([[ 5.03719345,  5.99006704,  4.4159709 , 16.48382901, -0.140062  ,
#         -1.66896603,  1.00517455, -2.15258941,  0.73576246]])

# %%
X_knn_prediction=knn.predict(X_knn_std)

# %%
category=['Employee will stay','Employee will leave']
category[int(X_knn_prediction)]
# Out:
# 'Employee will leave'

# %% [markdown]
# ##SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
model = SVC().fit(X_train_std,y_train)
pred = model.predict(X_test_std)
svc_accuracy = accuracy_score(y_test,pred)*100
print('Accuracy score : ',svc_accuracy)
scores_dict['SVC'] = svc_accuracy
print(classification_report(y_test,pred))
# Out:
# Accuracy score :  96.06666666666666
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      3417
#            1       0.92      0.91      0.92      1083
#
#     accuracy                           0.96      4500
#    macro avg       0.95      0.94      0.95      4500
# weighted avg       0.96      0.96      0.96      4500

# %%
from lightgbm import LGBMClassifier
model = LGBMClassifier(learning_rate=0.03,n_estimators=1000).fit(X_train_std,y_train)
pred = model.predict(X_test_std)
LGBM_accuracy = accuracy_score(y_test,pred)*100
print('Accuracy score : ',LGBM_accuracy)
scores_dict['LGBMClassifier'] = LGBM_accuracy
# Out:
# Accuracy score :  99.17777777777778

# %% [markdown]
# #Comparision of decision tree and knn

# %%
algo_name = list(scores_dict.keys())
accuracy_list = list(scores_dict.values())

sns.set(rc={'figure.figsize':(12.4,6.5)})
with sns.color_palette('muted'):
    sns.barplot(x=algo_name,y=accuracy_list)

# %%
scores_dict
# Out:
# {'DecisionTreeClassifier': 97.64444444444445,
#  'KNeighborsClassifier': 96.04444444444444,
#  'LGBMClassifier': 99.17777777777778,
#  'SVC': 96.06666666666666}
